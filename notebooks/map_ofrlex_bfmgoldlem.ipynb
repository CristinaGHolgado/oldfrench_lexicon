# %%
import pandas as pd
import csv
import glob
import os
import re
import numpy as np
pd.set_option('display.max_columns',20)
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_colwidth', None)
np.set_printoptions(linewidth=460)

# %% [markdown]
# ### Load inventories & preprocess before merging

# %%
# Input files
bfm_inventory = "inventaire_bfmgoldlem.tsv"
ofrlex_inventory = "inventaire_ofrlex.tsv"

# load files
bfm = pd.read_csv(bfm_inventory, sep='\t', encoding='utf-8', quoting=csv.QUOTE_NONE)
ofr = pd.read_csv(ofrlex_inventory, sep='\t', encoding='utf-8', quoting=csv.QUOTE_NONE)

# sort values
bfm = bfm.sort_values(by=['lemma'], ascending=True)
ofr = ofr.sort_values(by=['lemme'], ascending=True)

# preprocess bfm ofr dataframes
bfm.loc[bfm['cattex'] == "NOMpro", "lemma"] = bfm["lemma"].str.capitalize()
bfm.loc[bfm['cattex'] == "NOMpro", "form"] = bfm["form"].str.capitalize()

ofr.loc[ofr['upos'] == "PROPN", "lemme"] = ofr["lemme"].str.capitalize()
ofr.loc[ofr['upos'] == "PROPN", "form"] = ofr["form"].str.capitalize()

# fix œ linkage
bfm['lemma'] = bfm['lemma'].str.replace("œ","oe")
bfm['form'] = bfm['form'].str.replace("œ","oe")
bfm['flp'] = bfm['flp'].str.replace("œ","oe")


bfm['flp'] = bfm['flp'].str.replace("*","")
bfm['form'] = bfm['form'].str.replace("*","")
bfm['lemma'] = bfm['lemma'].str.replace("*","")
bfm['flp'] = bfm['flp'].str.replace('\d+', '')
ofr.loc[ofr.form == 'nan', 'form'] = ofr['form']+"__" # to avoid deleting forms that are actually 'nan' when 'fillna()' in pandas
ofr['form'] = ofr['form'].str.replace("§","")
ofr['flp'] = ofr['form'] + "_" + ofr['raw_lemme'] + "_" + ofr['upos'] # insert flp column (will be used to merge both dfs)

# col flp form_lemma_pos
bfm['flp'] = bfm['flp'].str.lower()
ofr['flp'] = ofr['flp'].str.lower()

# new col `fl` form_lemma
bfm['fl'] = bfm['form'].str.lower() + "_" + bfm['lemma'].str.lower()
ofr['fl'] = ofr['form'].str.lower() + "_" + ofr["raw_lemme"].str.lower()

# new col `fp` form_pos
bfm['fp'] = bfm['form'].str.lower() + "_" + bfm['flp'].apply(lambda x: x.split("_")[-1])
ofr['fp'] = ofr['form'].str.lower() + "_" + ofr["upos"].str.lower()

# ignore irrelevant cols
del bfm['occ_bfm']
del bfm['n'] # del col lemma number
del ofr['inconnu']

# rename bfm lemma column to avoid ocnfusion with lemma col from ofr
bfm.rename(columns = {'lemma':'lemma_bfm'}, inplace = True)
bfm.rename(columns = {'form':'form_bfm'}, inplace = True)

print(f"Entrées dans BFMGOLDLEM: {len(bfm)}")
print(f"Entrées dans OFrLex: {len(ofr)}")
# Out:
# Entrées dans BFMGOLDLEM: 31325
# Entrées dans OFrLex: 864083

# %% [markdown]
# #### Settings
# `merge_by_col` = column used as index to merge dataframes
# If `flp`: merge OFrLex and BFM data by **form_lemma_pos**
# If `fl`: merge OFrLex and BFM data by **form_lemma**
# If `fp`: merge OFrLex and BFM data by **form_pos**
#
# Each option outputs its own file

# %%
### settings

# set col `fl` (form,lemme) or `flp` (+pos) as index in both dataframes or `fp` (form, pos)
# used to match form-lemma pairs or form-lemma-pos or form-pos between ofrlex & bfm inventories
merge_by_col = 'flp'

# name for all inventory (bfm entries & ofrlex entries aligned), grouped by ofrlex lemmes
full_inventory_name = f"inventaire_{merge_by_col}_ofr-bfm.tsv"

# name for file containing shared entries
common_inventory_name = f"inventaire_{merge_by_col}_commun_ofr-bfm.tsv"

#
verb_inventory_name = f"inventaire_verbes_ofr-bfm_{merge_by_col}.tsv" 

# 
common_verb_inventory_name = f"inventaire_verbes_commun_ofr-bfm_{merge_by_col}.tsv"

# %% [markdown]
# ## Concat & group aligned ofrlex-bfmgoldlem items

# %% [markdown]
# #### Both tables (bfm & ofrlex) are merged with data aligned based on index, then sorted alphabeticallly by ofrlex lemmas
# - When an item is missing (e.g. ofrlex lemma) thw rows are filled with the info from the other table (e.g. bfm lemma). It allows to detect variants.
# - Items in row `lemmas` and `forms` ending up with an asterisk correpond to bfm entries

# %%
# set indexes
bfm.set_index(merge_by_col)
ofr.set_index(merge_by_col)

# Make new df that merges bfm & ofr dataframes by common col `flp` (form lemma pos)
df = ofr.merge(bfm, on=merge_by_col, how='outer').fillna("_")

# Sort df by ofrlex lemmas
df_sorted = df.sort_values('lemme', ascending=True)
print(f"Number of items : {len(df_sorted)}")

## inventaire ensemble ofr-bfm regroupe par lemme
inventaire_bfm_ofr = df_sorted

# insert bfm lemma/form in `lemme`(ofr) column as 'bfm:lemma_bfm' to allow grouping without deteleting empty rows (they correspond to lemmas specific to bfmgoldlem corpus)
# insert bfm form, "". 
inventaire_bfm_ofr.loc[inventaire_bfm_ofr.lemme == "_", "lemme"] = inventaire_bfm_ofr["lemma_bfm"] + "*" # insert bfm lemma in 'lemme'(ofr) there is no ofr lemme (that way we can see what lemmas are not in ofr)
inventaire_bfm_ofr.loc[inventaire_bfm_ofr.form == "_", "form"] = inventaire_bfm_ofr[merge_by_col].apply(lambda x: x.split("_")[0]) + "*" # insert bfm form in 'form' when """"""

# # NOMpro starting with capital letter
inventaire_bfm_ofr.loc[(inventaire_bfm_ofr.cattex == "NOMpro")&(inventaire_bfm_ofr.form.str.endswith("*")), "form"] = inventaire_bfm_ofr.form.str.capitalize()
inventaire_bfm_ofr.loc[(inventaire_bfm_ofr.cattex == "NOMpro")&(inventaire_bfm_ofr.lemme.str.endswith("*")), "lemme"] = inventaire_bfm_ofr.lemme.str.capitalize()
inventaire_bfm_ofr.loc[inventaire_bfm_ofr.upos == "PROPN", "lemme"] = inventaire_bfm_ofr.lemme.str.capitalize()

# group data by `lemme` (ofr)
inv_all_grouped = inventaire_bfm_ofr.groupby(['lemme','form','upos','traits','form_bfm','cattex','feats_bfm','no_upos','file_src']).size()
inv_all_grouped = inv_all_grouped.reset_index()
inv_all_grouped = inv_all_grouped.iloc[:, :-1]

inv_all_grouped.to_csv(full_inventory_name, sep='\t', encoding='utf-8', index=False, quoting=csv.QUOTE_NONE)

### Pour une meilleure visualisation du tableau utiliser:
# inv_all_grouped.loc[inv_all_grouped.lemme.duplicated(), ['lemme']] = ''
# Out:
# Number of items : 889183

# %%
# display rows
inv_all_grouped.loc[85:120]
# Out:
#                    lemme        form   upos  \
# 85   Affrican___54382__1    Affrican  PROPN
# 86   Affrican___54382__1    Affrican  PROPN
# 87   Affrican___54382__1   Affricans  PROPN
# 88   Affrican___54382__1   Affricans  PROPN
# 89    Affrike___54383__1     Affrike  PROPN
# 90   Affrique___54384__1    Affrique  PROPN
# 91             Africain*   Affrican*      _
# 92             Africain*  Alfricans*      _
# 93    Afriche___99999__1     Afriche  PROPN
# 94              Afrique*    Affrike*      _
# 95              Afrique*    Alfrike*      _
# 96              Afrique*   Aufrique*      _
# 97       Agag___99999__1        Agag  PROPN
# 98   Agamenon___54385__1    Agamenon  PROPN
# 99               Agapet*    Agapion*      _
# 100              Agapit*   Agapitus*      _
# 101      Agar___54386__1        Agar  PROPN
# 102    Agaran___99999__1      Agaran  PROPN
# 103   Agarans___99999__1     Agarans  PROPN
# 104    Agathe___54387__1      Agathe  PROPN
# 105    Agathe___54387__1     Agathes  PROPN
# 106                Agen*       Agen*      _
# 107             Agenais*    Agenois*      _
# 108             Agenais*    Agenoiz*      _
# 109   Agnelot___54388__1     Agnelot  PROPN
# 110     Agnes___54389__1       Agnes  PROPN
# 111                Agni*       Agni*      _
# 112     Agnès___54390__1       Agnès  PROPN
# 113  Agravain___54391__1    Agravain  PROPN
# 114            Agrevain*  Agravains*      _
# 115  Agrevain___54392__1    Agrevain  PROPN
# 116  Agrevain___54392__1   Agrevains  PROPN
# 117  Aguiflez___54393__1    Aguiflez  PROPN
# 118             Aguisel*   Aguiflez*      _
# 119             Aguisel*  Auguissel*      _
# 120   Aguisel___54394__1     Aguisel  PROPN
#
#                                                                     traits  \
# 85   [pred="Affrican___54382__1<Suj:(sn)>",upos=PROPN,cat=np,@pl.nom.masc]
# 86   [pred="Affrican___54382__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.obl.masc]
# 87   [pred="Affrican___54382__1<Suj:(sn)>",upos=PROPN,cat=np,@pl.obl.masc]
# 88   [pred="Affrican___54382__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.nom.masc]
# 89                 [pred="Affrike___54383__1<Suj:(sn)>",upos=PROPN,cat=np]
# 90                [pred="Affrique___54384__1<Suj:(sn)>",upos=PROPN,cat=np]
# 91                                                                       _
# 92                                                                       _
# 93                 [pred="Afriche___99999__1<Suj:(sn)>",upos=PROPN,cat=np]
# 94                                                                       _
# 95                                                                       _
# 96                                                                       _
# 97                    [pred="Agag___99999__1<Suj:(sn)>",upos=PROPN,cat=np]
# 98                [pred="Agamenon___54385__1<Suj:(sn)>",upos=PROPN,cat=np]
# 99                                                                       _
# 100                                                                      _
# 101                   [pred="Agar___54386__1<Suj:(sn)>",upos=PROPN,cat=np]
# 102                 [pred="Agaran___99999__1<Suj:(sn)>",upos=PROPN,cat=np]
# 103                [pred="Agarans___99999__1<Suj:(sn)>",upos=PROPN,cat=np]
# 104         [pred="Agathe___54387__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.fem]
# 105         [pred="Agathe___54387__1<Suj:(sn)>",upos=PROPN,cat=np,@pl.fem]
# 106                                                                      _
# 107                                                                      _
# 108                                                                      _
# 109                [pred="Agnelot___54388__1<Suj:(sn)>",upos=PROPN,cat=np]
# 110                  [pred="Agnes___54389__1<Suj:(sn)>",upos=PROPN,cat=np]
# 111                                                                      _
# 112                  [pred="Agnès___54390__1<Suj:(sn)>",upos=PROPN,cat=np]
# 113               [pred="Agravain___54391__1<Suj:(sn)>",upos=PROPN,cat=np]
# 114                                                                      _
# 115  [pred="Agrevain___54392__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.obl.masc]
# 116  [pred="Agrevain___54392__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.nom.masc]
# 117               [pred="Aguiflez___54393__1<Suj:(sn)>",upos=PROPN,cat=np]
# 118                                                                      _
# 119                                                                      _
# 120                [pred="Aguisel___54394__1<Suj:(sn)>",upos=PROPN,cat=np]
#
#       form_bfm  cattex feats_bfm no_upos                 file_src
# 85           _       _         _       0  ../ofrlex-dev\PROPN.lex
# 86           _       _         _       0  ../ofrlex-dev\PROPN.lex
# 87           _       _         _       0  ../ofrlex-dev\PROPN.lex
# 88           _       _         _       0  ../ofrlex-dev\PROPN.lex
# 89           _       _         _       0  ../ofrlex-dev\PROPN.lex
# 90           _       _         _       0  ../ofrlex-dev\PROPN.lex
# 91    Affrican  NOMpro         _       _                        _
# 92   Alfricans  NOMpro         _       _                        _
# 93           _       _         _       0  ../ofrlex-dev\PROPN.lex
# 94     Affrike  NOMpro         _       _                        _
# 95     Alfrike  NOMpro         _       _                        _
# 96    Aufrique  NOMpro         _       _                        _
# 97           _       _         _       0  ../ofrlex-dev\PROPN.lex
# 98           _       _         _       0  ../ofrlex-dev\PROPN.lex
# 99     Agapion  NOMpro         _       _                        _
# 100   Agapitus  NOMpro         _       _                        _
# 101          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 102          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 103          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 104          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 105          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 106       Agen  NOMpro         _       _                        _
# 107    Agenois  NOMpro         _       _                        _
# 108    Agenoiz  NOMpro         _       _                        _
# 109          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 110          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 111       Agni  NOMpro         _       _                        _
# 112          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 113          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 114  Agravains  NOMpro         _       _                        _
# 115          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 116  Agrevains  NOMpro         _       0  ../ofrlex-dev\PROPN.lex
# 117          _       _         _       0  ../ofrlex-dev\PROPN.lex
# 118   Aguiflez  NOMpro         _       _                        _
# 119  Auguissel  NOMpro         _       _                        _
# 120          _       _         _       0  ../ofrlex-dev\PROPN.lex

# %% [markdown]
# ### Common lemmas (based on selected index merging)

# %% [markdown]
# #### Sauvegarder lemmes en commun

# %%
## inventaire items en commun () regroupes par lemmes ofr
inventaire_commun = inv_all_grouped.loc[(inv_all_grouped['traits'] != "_") & (inv_all_grouped['cattex'] != "_")]

print()
print(f">>> Paires {merge_by_col} en commun : {len(inventaire_commun)}")
print()
inventaire_commun.to_csv(common_inventory_name, sep='\t', encoding='utf-8', index=False, quoting=csv.QUOTE_NONE)
inventaire_commun[:10]
# Out:
# >>> Paires flp en commun : 14695
#                     lemme       form   upos  \
# 17        Abel___54354__1       Abel  PROPN
# 26      Abisme___99999__1     Abisme  PROPN
# 29     Abraham___54362__1    Abraham  PROPN
# 30     Abrahan___54363__1    Abrahan  PROPN
# 36      Acelin___99999__1     Acelin  PROPN
# 50      Acorde___54370__1     Acorde  PROPN
# 54   Acorionde___54371__1  Acorionde  PROPN
# 63        Adam___54375__1       Adam  PROPN
# 75       Aelis___54380__1      Aelis  PROPN
# 116   Agrevain___54392__1  Agrevains  PROPN
#
#                                                                     traits  \
# 17       [pred="Abel___54354__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.obl.masc]
# 26         [pred="Abisme___99999__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.masc]
# 29                 [pred="Abraham___54362__1<Suj:(sn)>",upos=PROPN,cat=np]
# 30    [pred="Abrahan___54363__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.obl.masc]
# 36         [pred="Acelin___99999__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.masc]
# 50          [pred="Acorde___54370__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.fem]
# 54               [pred="Acorionde___54371__1<Suj:(sn)>",upos=PROPN,cat=np]
# 63       [pred="Adam___54375__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.obl.masc]
# 75                   [pred="Aelis___54380__1<Suj:(sn)>",upos=PROPN,cat=np]
# 116  [pred="Agrevain___54392__1<Suj:(sn)>",upos=PROPN,cat=np,@sg.nom.masc]
#
#       form_bfm  cattex feats_bfm no_upos                 file_src
# 17        Abel  NOMpro         _       0  ../ofrlex-dev\PROPN.lex
# 26      Abisme  NOMpro         _       0  ../ofrlex-dev\PROPN.lex
# 29     Abraham  NOMpro         _       0  ../ofrlex-dev\PROPN.lex
# 30     Abrahan  NOMpro         _       0  ../ofrlex-dev\PROPN.lex
# 36      Acelin  NOMpro         _       0  ../ofrlex-dev\PROPN.lex
# 50      Acorde  NOMpro         _       0  ../ofrlex-dev\PROPN.lex
# 54   Acorionde  NOMpro         _       0  ../ofrlex-dev\PROPN.lex
# 63        Adam  NOMpro         _       0  ../ofrlex-dev\PROPN.lex
# 75       Aelis  NOMpro         _       0  ../ofrlex-dev\PROPN.lex
# 116  Agrevains  NOMpro         _       0  ../ofrlex-dev\PROPN.lex

# %% [markdown]
# ### Inventory for verbs

# %% [markdown]
# #### Sauvegarder les entrees pour les verbes (inventaire verbes)

# %%
## inventaire verbes (regroupes par lemme)
# select rows that are verbs (bfm and ofrlex)
verbs = inventaire_bfm_ofr.loc[(inventaire_bfm_ofr['upos'] == "VERB")|(inventaire_bfm_ofr['cattex'].str.contains("VER"))]

# regroup
verbs = verbs.groupby(['lemme','form','upos','traits','form_bfm','cattex','feats_bfm','no_upos','file_src']).size()
verbs = verbs.reset_index()
verbs = verbs.iloc[:, :-1]

# sauvegarder tous les verbes (soit ofr, soit bfm)
all_verbs = verbs
all_verbs.to_csv(verb_inventory_name, sep='\t', encoding='utf-8', index=False, quoting=csv.QUOTE_NONE)
all_verbs[7:20]
# Out:
#                       lemme      form  upos  \
# 7    aaidier___746692__1__1   aaidier  VERB
# 8   aaignier___746693__1__1  aaignier  VERB
# 9    aairier___746694__1__1   aairier  VERB
# 10                  aaiser*    aeise*     _
# 11                  aaiser*  aeisent*     _
# 12                  aaiser*  aeisiee*     _
# 13                  aaiser*  aeisier*     _
# 14                  aaiser*  aeisiez*     _
# 15                  aaiser*   aeisié*     _
# 16   aaisier___746695__1__1      aais  VERB
# 17   aaisier___746695__1__1      aais  VERB
# 18   aaisier___746695__1__1      aais  VERB
# 19   aaisier___746695__1__1     aaisa  VERB
#
#                                                                                            traits  \
# 7             [pred="aaidier___746692__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 8            [pred="aaignier___746693__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 9                          [pred="aairier___746694__1__1<Suj:cln|sn>",@pers,cat=v,upos=VERB,@inf]
# 10                                                                                              _
# 11                                                                                              _
# 12                                                                                              _
# 13                                                                                              _
# 14                                                                                              _
# 15                                                                                              _
# 16   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.1.ind.prs]
# 17  [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.1.subj.prs]
# 18  [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.2.subj.prs]
# 19   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.pst]
#
#    form_bfm  cattex                 feats_bfm no_upos                file_src
# 7         _       _                         _       0  ../ofrlex-dev\VERB.lex
# 8         _       _                         _       0  ../ofrlex-dev\VERB.lex
# 9         _       _                         _       0  ../ofrlex-dev\VERB.lex
# 10    aeise  VERcjg              VerbForm=Fin       _                       _
# 11  aeisent  VERcjg              VerbForm=Fin       _                       _
# 12  aeisiee  VERppe  VerbForm=Part|Tense=Past       _                       _
# 13  aeisier  VERinf              VerbForm=Inf       _                       _
# 14  aeisiez  VERppe  VerbForm=Part|Tense=Past       _                       _
# 15   aeisié  VERppe  VerbForm=Part|Tense=Past       _                       _
# 16        _       _                         _       0  ../ofrlex-dev\VERB.lex
# 17        _       _                         _       0  ../ofrlex-dev\VERB.lex
# 18        _       _                         _       0  ../ofrlex-dev\VERB.lex
# 19        _       _                         _       0  ../ofrlex-dev\VERB.lex

# %%
# sauvegarder uniquement les verbes en commun (à partir les verbes ofrlex)
verbes_commun = verbs.loc[(verbs['upos'].str.contains("VERB")) & (verbs['cattex'] != "_")]
verbes_commun.to_csv(common_verb_inventory_name, sep='\t', encoding='utf-8', index=False, quoting=csv.QUOTE_NONE)

verbes_commun[:10]
# Out:
#                         lemme        form  upos  \
# 3885   abonder___746785__1__1      abonde  VERB
# 3886   abonder___746785__1__1      abonde  VERB
# 4266   aborrer___746793__1__1      aborré  VERB
# 5323   abriver___746821__1__1      abrivé  VERB
# 5536  abstenir___746832__1__1    abstenir  VERB
# 7165  aceindre___746866__1__1  aceindrons  VERB
# 7181  aceindre___746866__1__1      aceint  VERB
# 7182  aceindre___746866__1__1      aceint  VERB
# 7929   acesmer___746881__1__1     acesmer  VERB
# 7946   acesmer___746881__1__1     acesmez  VERB
#
#                                                                                              traits  \
# 3885       [pred="abonder___746785__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.2.imp]
# 3886   [pred="abonder___746785__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.prs]
# 4266       [pred="aborrer___746793__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@ptcp.pst]
# 5323       [pred="abriver___746821__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@ptcp.pst]
# 5536           [pred="abstenir___746832__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 7165  [pred="aceindre___746866__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.1.ind.fut]
# 7181      [pred="aceindre___746866__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@ptcp.pst]
# 7182  [pred="aceindre___746866__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.prs]
# 7929            [pred="acesmer___746881__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 7946       [pred="acesmer___746881__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.imp]
#
#         form_bfm          cattex                               feats_bfm  \
# 3885      abonde          VERcjg                            VerbForm=Fin
# 3886      abonde          VERcjg                            VerbForm=Fin
# 4266      aborré          VERppe                VerbForm=Part|Tense=Past
# 5323      abrivé          VERppe                VerbForm=Part|Tense=Past
# 5536    abstenir          VERinf                            VerbForm=Inf
# 7165  aceindrons          VERcjg                            VerbForm=Fin
# 7181      aceint  VERppe, VERcjg  VerbForm=Part|Tense=Past, VerbForm=Fin
# 7182      aceint  VERppe, VERcjg  VerbForm=Part|Tense=Past, VerbForm=Fin
# 7929     acesmer          VERinf                            VerbForm=Inf
# 7946     acesmez          VERppe                VerbForm=Part|Tense=Past
#
#      no_upos                file_src
# 3885       0  ../ofrlex-dev\VERB.lex
# 3886       0  ../ofrlex-dev\VERB.lex
# 4266       0  ../ofrlex-dev\VERB.lex
# 5323       0  ../ofrlex-dev\VERB.lex
# 5536       0  ../ofrlex-dev\VERB.lex
# 7165       0  ../ofrlex-dev\VERB.lex
# 7181       0  ../ofrlex-dev\VERB.lex
# 7182       0  ../ofrlex-dev\VERB.lex
# 7929       0  ../ofrlex-dev\VERB.lex
# 7946       0  ../ofrlex-dev\VERB.lex
