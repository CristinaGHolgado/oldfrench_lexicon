# %%
import pandas as pd
import csv
import glob
import os
import re
import numpy as np
pd.set_option('display.max_columns',20)
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_colwidth', None)
np.set_printoptions(linewidth=460)
from IPython.display import display, HTML

# %% [markdown]
# ### Load inventories & preprocess before merging

# %%
# Input files
bfm_inventory = "inventaire_bfm.tsv"
ofrlex_inventory = "inventaire_ofrlex.tsv"

# load files
bfm = pd.read_csv(bfm_inventory, sep='\t', encoding='utf-8', quoting=csv.QUOTE_NONE)
ofr = pd.read_csv(ofrlex_inventory, sep='\t', encoding='utf-8', quoting=csv.QUOTE_NONE)

# sort values
bfm = bfm.sort_values(by=['lemma'], ascending=True)
ofr = ofr.sort_values(by=['lemme'], ascending=True)

# preprocess bfm ofr dataframes
bfm['flp'] = bfm['flp'].str.replace("*","")
bfm['flp'] = bfm['flp'].str.replace('\d+', '')
ofr.loc[ofr.form == 'nan', 'form'] = ofr['form']+"__" # to avoid deleting forms that are actually 'nan' when 'fillna()' in pandas
ofr['form'] = ofr['form'].str.replace("§","")
ofr['flp'] = ofr['form'] + "_" + ofr['raw_lemme'] + "_" + ofr['upos'] # insert flp column (will be used to merge both dfs)
bfm['flp'] = bfm['flp'].str.lower()
ofr['flp'] = ofr['flp'].str.lower()

# new col `fl` for form+lemme
bfm['fl'] = bfm['form'] + "_" + bfm['lemma']
ofr['fl'] = ofr['form'] + "_" + ofr["raw_lemme"]

# ignore irrelevant cols
del bfm['occ_bfm']
del bfm['form'] # form is already existing in flp col
del bfm['n'] # del col lemma number
del ofr['inconnu']

# rename bfm lemma column to avoid ocnfusion with lemma col from ofr
bfm.rename(columns = {'lemma':'lemma_bfm'}, inplace = True)

print(f"Entrées dans BFMGOLDLEM: {len(bfm)}")
print(f"Entrées dans OFrLex: {len(ofr)}")
# Out:
# Entrées dans BFMGOLDLEM: 31325
# Entrées dans OFrLex: 864083

# %%
### settings

# set col `fl` (form lemme) or `flp` (+pos) as index in both dataframes
# used to match form-lemma pairs or form-lemma-pos between ofrlex & bfm inventories
merge_by_col = 'fl'

# name for all inventory (bfm entries & ofrlex entries aligned), grouped by ofrlex lemmes
full_inventory_name = f"inventaire_{merge_by_col}_ofr-bfm.tsv"

# name for file containing shared entries
common_inventory_name = f"inventaire_{merge_by_col}_commun_ofr-bfm.tsv"

#
verb_inventory_name = f"inventaire_verbes_ofr-bfm_{merge_by_col}.tsv" 

# 
common_verb_inventory_name = f"inventaire_verbes_commun_ofr-bfm_{merge_by_col}.tsv"

# %% [markdown]
# ### Concat & group aligned ofrlex-bfmgoldlem form-lemma-pos/form-lemma by OFrLex lemmas

# %%
# set indexes
bfm.set_index(merge_by_col)
ofr.set_index(merge_by_col)

# Make new df that merges bfm & ofr dataframes by common col `flp` (form lemma pos)
df = ofr.merge(bfm, on=merge_by_col, how='outer').fillna("_")

# Sort df by ofrlex lemmas
df_sorted = df.sort_values('lemme', ascending=True)
print(f"Number of shared items : {len(df_sorted)}")

## inventaire ensemble ofr-bfm regroupe par lemme
inventaire_bfm_ofr = df_sorted

# insert bfm lemma/form in `lemme`(ofr) column as 'bfm:lemma_bfm' to allow grouping without deteleting empty rows (they correspond to lemmas specific to bfmgoldlem corpus)
# insert bfm form, "". 
inventaire_bfm_ofr.loc[inventaire_bfm_ofr.lemme == "_", "lemme"] = "bfm:" + inventaire_bfm_ofr["lemma_bfm"] # insert bfm lemma in 'lemme'(ofr) there is no ofr lemme (that way we can see what lemmas are not in ofr)
inventaire_bfm_ofr.loc[inventaire_bfm_ofr.form == "_", "form"] = "bfm:" + inventaire_bfm_ofr[merge_by_col].apply(lambda x: x.split("_")[0]) # insert bfm form in 'form' when """"""

# group data by `lemme` (ofr)
inv_all_grouped = inventaire_bfm_ofr.groupby(['lemme','form','upos','traits','cattex','feats_bfm','no_upos','file_src']).size()
inv_all_grouped = inv_all_grouped.reset_index()
inv_all_grouped = inv_all_grouped.iloc[:, :-1]

inv_all_grouped.to_csv(full_inventory_name, sep='\t', encoding='utf-8', index=False, quoting=csv.QUOTE_NONE)

### Pour une meilleure visualisation du tableau utiliser:
# inv_all_grouped.loc[inv_all_grouped.lemme.duplicated(), ['lemme']] = ''
# Out:
# Items in shared inventory : 891151

# %% [markdown]
# #### Sauvegarder lemmes en commun

# %%
## inventaire items en commun () regroupes par lemmes ofr
inventaire_commun = inv_all_grouped.loc[(inv_all_grouped['traits'] != "_") & (inv_all_grouped['cattex'] != "_")]

print()
print(f">>> Paires {merge_by_col} en commun : {len(inventaire_commun)}")
print()
inventaire_commun.to_csv(common_inventory_name, sep='\t', encoding='utf-8', index=False, quoting=csv.QUOTE_NONE)
inventaire_commun[:30]
# Out:
# >>> Paires fl en commun : 18747
#                          lemme        form  upos  \
# 3982             aate___203__1       aates   ADJ
# 3983             aate___203__1       aates   ADJ
# 3984             aate___203__1       aates   ADJ
# 6117           abel___10361__1        abel  NOUN
# 6118           abel___10361__1        abel  NOUN
# 7027         abisme___10398__1      abisme  NOUN
# 7028         abisme___10398__1      abisme  NOUN
# 7029         abisme___10398__1      abisme  NOUN
# 7364           able___10412__1        able  NOUN
# 7365           able___10412__1        able  NOUN
# 7366           able___10412__1        able  NOUN
# 7369             able___218__1        able   ADJ
# 7370             able___218__1        able   ADJ
# 7371             able___218__1        able   ADJ
# 7376             able___219__1        able   ADJ
# 7377             able___219__1        able   ADJ
# 7378             able___219__1        able   ADJ
# 8241    abonder___746785__1__1      abonde  VERB
# 8242    abonder___746785__1__1      abonde  VERB
# 8664    aborrer___746793__1__1      aborré  VERB
# 9871    abriver___746821__1__1      abrivé  VERB
# 10172  abstenir___746832__1__1    abstenir  VERB
# 11395      accident___10522__1    accident  NOUN
# 11396      accident___10522__1    accident  NOUN
# 11983  aceindre___746866__1__1  aceindrons  VERB
# 11999  aceindre___746866__1__1      aceint  VERB
# 12000  aceindre___746866__1__1      aceint  VERB
# 12949   acesmer___746881__1__1     acesmer  VERB
# 12966   acesmer___746881__1__1     acesmez  VERB
# 12967   acesmer___746881__1__1     acesmez  VERB
#
#                                                                                                 traits  \
# 3982                                 [pred="aate___203__1<Suj:cln|sn>",@pers,cat=adj,upos=ADJ,@pl.fem]
# 3983                            [pred="aate___203__1<Suj:cln|sn>",@pers,cat=adj,upos=ADJ,@pl.obl.masc]
# 3984                            [pred="aate___203__1<Suj:cln|sn>",@pers,cat=adj,upos=ADJ,@sg.nom.masc]
# 6117       [pred="abel___10361__1<Objde:(de-sinf|de-sn),Objà:(à-sinf)>",upos=NOUN,cat=nc,@pl.nom.masc]
# 6118       [pred="abel___10361__1<Objde:(de-sinf|de-sn),Objà:(à-sinf)>",upos=NOUN,cat=nc,@sg.obl.masc]
# 7027     [pred="abisme___10398__1<Objde:(de-sinf|de-sn),Objà:(à-sinf)>",upos=NOUN,cat=nc,@pl.nom.masc]
# 7028          [pred="abisme___10398__1<Objde:(de-sinf|de-sn),Objà:(à-sinf)>",upos=NOUN,cat=nc,@sg.fem]
# 7029     [pred="abisme___10398__1<Objde:(de-sinf|de-sn),Objà:(à-sinf)>",upos=NOUN,cat=nc,@sg.obl.masc]
# 7364       [pred="able___10412__1<Objde:(de-sinf|de-sn),Objà:(à-sinf)>",upos=NOUN,cat=nc,@pl.nom.masc]
# 7365       [pred="able___10412__1<Objde:(de-sinf|de-sn),Objà:(à-sinf)>",upos=NOUN,cat=nc,@sg.obl.masc]
# 7366                    [pred="able___10412__1<Objde:(de-sinf|de-sn),Objà:(à-sinf)>",upos=NOUN,cat=nc]
# 7369                            [pred="able___218__1<Suj:cln|sn>",@pers,cat=adj,upos=ADJ,@pl.nom.masc]
# 7370                                 [pred="able___218__1<Suj:cln|sn>",@pers,cat=adj,upos=ADJ,@sg.fem]
# 7371                            [pred="able___218__1<Suj:cln|sn>",@pers,cat=adj,upos=ADJ,@sg.obl.masc]
# 7376                            [pred="able___219__1<Suj:cln|sn>",@pers,cat=adj,upos=ADJ,@pl.nom.masc]
# 7377                                 [pred="able___219__1<Suj:cln|sn>",@pers,cat=adj,upos=ADJ,@sg.fem]
# 7378                            [pred="able___219__1<Suj:cln|sn>",@pers,cat=adj,upos=ADJ,@sg.obl.masc]
# 8241          [pred="abonder___746785__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.2.imp]
# 8242      [pred="abonder___746785__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.prs]
# 8664          [pred="aborrer___746793__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@ptcp.pst]
# 9871          [pred="abriver___746821__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@ptcp.pst]
# 10172             [pred="abstenir___746832__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 11395  [pred="accident___10522__1<Objde:(de-sinf|de-sn),Objà:(à-sinf)>",upos=NOUN,cat=nc,@pl.nom.masc]
# 11396  [pred="accident___10522__1<Objde:(de-sinf|de-sn),Objà:(à-sinf)>",upos=NOUN,cat=nc,@sg.obl.masc]
# 11983    [pred="aceindre___746866__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.1.ind.fut]
# 11999        [pred="aceindre___746866__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@ptcp.pst]
# 12000    [pred="aceindre___746866__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.prs]
# 12949              [pred="acesmer___746881__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 12966         [pred="acesmer___746881__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.imp]
# 12967     [pred="acesmer___746881__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.ind.prs]
#
#                cattex                               feats_bfm no_upos  \
# 3982           ADJqua                                       _       0
# 3983           ADJqua                                       _       0
# 3984           ADJqua                                       _       0
# 6117           NOMpro                                       _       0
# 6118           NOMpro                                       _       0
# 7027           NOMpro                                       _       0
# 7028           NOMpro                                       _       0
# 7029           NOMpro                                       _       0
# 7364           ADJqua                                       _       0
# 7365           ADJqua                                       _       0
# 7366           ADJqua                                       _       0
# 7369           ADJqua                                       _       0
# 7370           ADJqua                                       _       0
# 7371           ADJqua                                       _       0
# 7376           ADJqua                                       _       0
# 7377           ADJqua                                       _       0
# 7378           ADJqua                                       _       0
# 8241           VERcjg                            VerbForm=Fin       0
# 8242           VERcjg                            VerbForm=Fin       0
# 8664           VERppe                VerbForm=Part|Tense=Past       0
# 9871           VERppe                VerbForm=Part|Tense=Past       0
# 10172          VERinf                            VerbForm=Inf       0
# 11395          NOMcom                                       _       0
# 11396          NOMcom                                       _       0
# 11983          VERcjg                            VerbForm=Fin       0
# 11999  VERppe, VERcjg  VerbForm=Part|Tense=Past, VerbForm=Fin       0
# 12000  VERppe, VERcjg  VerbForm=Part|Tense=Past, VerbForm=Fin       0
# 12949          VERinf                            VerbForm=Inf       0
# 12966          VERppe                VerbForm=Part|Tense=Past       0
# 12967          VERppe                VerbForm=Part|Tense=Past       0
#
#                      file_src
# 3982    ../ofrlex-dev\ADJ.lex
# 3983    ../ofrlex-dev\ADJ.lex
# 3984    ../ofrlex-dev\ADJ.lex
# 6117   ../ofrlex-dev\NOUN.lex
# 6118   ../ofrlex-dev\NOUN.lex
# 7027   ../ofrlex-dev\NOUN.lex
# 7028   ../ofrlex-dev\NOUN.lex
# 7029   ../ofrlex-dev\NOUN.lex
# 7364   ../ofrlex-dev\NOUN.lex
# 7365   ../ofrlex-dev\NOUN.lex
# 7366   ../ofrlex-dev\NOUN.lex
# 7369    ../ofrlex-dev\ADJ.lex
# 7370    ../ofrlex-dev\ADJ.lex
# 7371    ../ofrlex-dev\ADJ.lex
# 7376    ../ofrlex-dev\ADJ.lex
# 7377    ../ofrlex-dev\ADJ.lex
# 7378    ../ofrlex-dev\ADJ.lex
# 8241   ../ofrlex-dev\VERB.lex
# 8242   ../ofrlex-dev\VERB.lex
# 8664   ../ofrlex-dev\VERB.lex
# 9871   ../ofrlex-dev\VERB.lex
# 10172  ../ofrlex-dev\VERB.lex
# 11395  ../ofrlex-dev\NOUN.lex
# 11396  ../ofrlex-dev\NOUN.lex
# 11983  ../ofrlex-dev\VERB.lex
# 11999  ../ofrlex-dev\VERB.lex
# 12000  ../ofrlex-dev\VERB.lex
# 12949  ../ofrlex-dev\VERB.lex
# 12966  ../ofrlex-dev\VERB.lex
# 12967  ../ofrlex-dev\VERB.lex

# %% [markdown]
# #### Sauvegarder les entrees pour les verbes (inventaire verbes)

# %%
## inventaire verbes (regroupes par lemme)
# select rows that are verbs
verbs = inventaire_bfm_ofr.loc[(inventaire_bfm_ofr['upos'] == "VERB" )]
verbs = verbs.groupby(['lemme','form','upos','traits','cattex','feats_bfm','no_upos','file_src']).size()
verbs = verbs.reset_index()
verbs = verbs.iloc[:, :-1]

# sauvegarder tous les verbes (soit ofr, soit bfm)
all_verbs = verbs
all_verbs.to_csv(verb_inventory_name, sep='\t', encoding='utf-8', index=False, quoting=csv.QUOTE_NONE)
all_verbs[:50]
# Out:
#                       lemme         form  upos  \
# 0     aacier___746691__1__1       aacier  VERB
# 1      aagié___999999__1__1        aagié  VERB
1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 8             [pred="aaignier___746693__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 9                           [pred="aairier___746694__1__1<Suj:cln|sn>",@pers,cat=v,upos=VERB,@inf]
# 10    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.1.ind.prs]
# 11   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.1.subj.prs]
# 12   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.2.subj.prs]
# 13    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.pst]
# 14    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.1.ind.pst]
# 15    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.1.ind.pst]
# 16        [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@ptcp.prs]
# 17    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.2.ind.pst]
# 18   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.1.subj.ipf]
# 19   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.subj.ipf]
# 20   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.2.subj.ipf]
# 21   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.subj.ipf]
# 22    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.ind.pst]
# 23        [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.2.imp]
# 24    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.prs]
# 25    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.ind.prs]
# 26   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.subj.prs]
# 27    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.fut]
# 28    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.1.ind.fut]
# 29    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.2.ind.fut]
# 30    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.ind.fut]
# 31   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.cond.prs]
# 32   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.1.cond.prs]
# 33   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.1.cond.prs]
# 34   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.cond.prs]
# 35   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.2.cond.prs]
# 36   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.cond.prs]
# 37    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.ind.fut]
# 38    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.1.ind.fut]
# 39    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.ind.fut]
# 40    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.2.ind.prs]
# 41   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.1.subj.prs]
# 42             [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 43    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.ind.pst]
# 44        [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.imp]
# 45    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.ind.prs]
# 46   [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.subj.prs]
# 47    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.1.ind.ipf]
# 48    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.ind.ipf]
# 49    [pred="aaisier___746695__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.1.ind.ipf]
#
#    cattex feats_bfm  no_upos                                 file_src
# 0       _         _      0.0                   ../ofrlex-dev\VERB.lex
# 1       _         _      0.0                   ../ofrlex-dev\VERB.lex
# 2       _         _      0.0   ../ofrlex-dev\mod-lex\VERppe-actif.lex
# 3       _         _      0.0                   ../ofrlex-dev\VERB.lex
# 4       _         _      0.0     ../ofrlex-dev\mod-lex\VERppe-ppp.lex
# 5       _         _      0.0                   ../ofrlex-dev\VERB.lex
# 6       _         _      0.0  ../ofrlex-dev\mod-lex\VERppe-passif.lex
# 7       _         _      0.0                   ../ofrlex-dev\VERB.lex
# 8       _         _      0.0                   ../ofrlex-dev\VERB.lex
# 9       _         _      0.0                   ../ofrlex-dev\VERB.lex
# 10      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 11      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 12      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 13      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 14      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 15      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 16      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 17      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 18      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 19      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 20      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 21      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 22      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 23      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 24      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 25      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 26      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 27      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 28      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 29      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 30      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 31      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 32      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 33      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 34      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 35      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 36      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 37      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 38      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 39      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 40      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 41      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 42      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 43      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 44      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 45      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 46      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 47      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 48      _         _      0.0                   ../ofrlex-dev\VERB.lex
# 49      _         _      0.0                   ../ofrlex-dev\VERB.lex

# %%
# sauvegarder uniquement les verbes en commun (à partir les verbes ofrlex)
verbes_commun = verbs.loc[(verbs['upos'].str.contains("upos=VERB")) & (verbs['cattex'] != "_")]
verbes_commun.to_csv(common_verb_inventory_name, sep='\t', encoding='utf-8', index=False, quoting=csv.QUOTE_NONE)

verbes_commun[:50]
# Out:
#                           lemme          form  upos  \
# 3818     abonder___746785__1__1        abonde  VERB
# 3819     abonder___746785__1__1        abonde  VERB
# 4197     aborrer___746793__1__1        aborré  VERB
1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.ind.pst]
# 8847   [pred="acheter___746906__1__1<Suj:cln|sn,Obj:(cla|sn),Objde:(de-sn),Obl:(par-sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.pst]
# 8848   [pred="acheter___746906__1__1<Suj:cln|sn,Obj:(cla|sn),Objde:(de-sn),Obl:(par-sn)>",@pers,cat=v,upos=VERB,@sg.1.ind.pst]
# 8861            [pred="acheter___746906__1__1<Suj:cln|sn,Obj:(cla|sn),Objde:(de-sn),Obl:(par-sn)>",@pers,cat=v,upos=VERB,@inf]
# 8896       [pred="acheter___746906__1__1<Suj:cln|sn,Obj:(cla|sn),Objde:(de-sn),Obl:(par-sn)>",@pers,cat=v,upos=VERB,@ptcp.pst]
# 8939                 [pred="achever___746908__1__1<Suj:cln|sn,Obj:(cla|sn),Obl:(par-sn)>",@pers,cat=v,upos=VERB,@sg.2.ind.fut]
# 8972                     [pred="achever___746908__1__1<Suj:cln|sn,Obj:(cla|sn),Obl:(par-sn)>",@pers,cat=v,upos=VERB,@ptcp.pst]
# 9381              [pred="acliner___746919__1__1<Suj:cln|sn,Obj:(cla|sn),Objà:(cld|à-sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.pst]
# 9391                  [pred="acliner___746919__1__1<Suj:cln|sn,Obj:(cla|sn),Objà:(cld|à-sn)>",@pers,cat=v,upos=VERB,@sg.2.imp]
# 9392                  [pred="acliner___746919__1__1<Suj:cln|sn,Obj:(cla|sn),Objà:(cld|à-sn)>",@pers,cat=v,upos=VERB,@sg.2.imp]
# 9393              [pred="acliner___746919__1__1<Suj:cln|sn,Obj:(cla|sn),Objà:(cld|à-sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.prs]
# 9394              [pred="acliner___746919__1__1<Suj:cln|sn,Obj:(cla|sn),Objà:(cld|à-sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.prs]
# 11585              [pred="acorer___746971__1__1<Suj:cln|sn,Obj:(cla|scompl|sn),Objà:(cld|y|à-sn)>",@pers,cat=v,upos=VERB,@inf]
# 11601         [pred="acorer___746971__1__1<Suj:cln|sn,Obj:(cla|scompl|sn),Objà:(cld|y|à-sn)>",@pers,cat=v,upos=VERB,@pl.2.imp]
# 11602     [pred="acorer___746971__1__1<Suj:cln|sn,Obj:(cla|scompl|sn),Objà:(cld|y|à-sn)>",@pers,cat=v,upos=VERB,@pl.2.ind.prs]
# 11603    [pred="acorer___746971__1__1<Suj:cln|sn,Obj:(cla|scompl|sn),Objà:(cld|y|à-sn)>",@pers,cat=v,upos=VERB,@pl.2.subj.prs]
# 11622         [pred="acorer___746971__1__1<Suj:cln|sn,Obj:(cla|scompl|sn),Objà:(cld|y|à-sn)>",@pers,cat=v,upos=VERB,@ptcp.pst]
# 15653            [pred="adeser___747064__1__1<Suj:cln|sn,Obj:(cla|sn),Objà:(cld|y|à-sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.pst]
# 15661           [pred="adeser___747064__1__1<Suj:cln|sn,Obj:(cla|sn),Objà:(cld|y|à-sn)>",@pers,cat=v,upos=VERB,@sg.3.subj.ipf]
# 15667                     [pred="adeser___747064__1__1<Suj:cln|sn,Obj:(cla|sn),Objà:(cld|y|à-sn)>",@pers,cat=v,upos=VERB,@inf]
# 15671            [pred="adeser___747064__1__1<Suj:cln|sn,Obj:(cla|sn),Objà:(cld|y|à-sn)>",@pers,cat=v,upos=VERB,@pl.3.ind.pst]
# 15707                              [pred="adeser___747065__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.ind.pst]
# 15715                             [pred="adeser___747065__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@sg.3.subj.ipf]
# 15721                                       [pred="adeser___747065__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 15725                              [pred="adeser___747065__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.ind.pst]
# 16147                                  [pred="adirer___747080__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.imp]
# 16148                              [pred="adirer___747080__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.ind.prs]
# 16149                             [pred="adirer___747080__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.subj.prs]
# 17158                              [pred="adorer___747105__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.ind.prs]
# 17159                             [pred="adorer___747105__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.subj.prs]
# 17160                                       [pred="adorer___747105__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@inf]
# 17290                                 [pred="adosser___747107__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.imp]
# 17291                             [pred="adosser___747107__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.ind.prs]
# 17292                            [pred="adosser___747107__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.2.subj.prs]
# 17309                                 [pred="adosser___747107__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@ptcp.pst]
# 18218                              [pred="aduner___747127__1__1<Suj:cln|sn,Obj:(cla|sn)>",@pers,cat=v,upos=VERB,@pl.3.ind.prs]
#
#                cattex                               feats_bfm  no_upos  \
# 3818           VERcjg                            VerbForm=Fin      0.0
# 3819           VERcjg                            VerbForm=Fin      0.0
# 4197           VERppe                VerbForm=Part|Tense=Past      0.0
# 5248           VERppe                VerbForm=Part|Tense=Past      0.0
# 5451           VERinf                            VerbForm=Inf      0.0
# 6973           VERcjg                            VerbForm=Fin      0.0
# 6989   VERppe, VERcjg  VerbForm=Part|Tense=Past, VerbForm=Fin      0.0
# 6990   VERppe, VERcjg  VerbForm=Part|Tense=Past, VerbForm=Fin      0.0
# 7736           VERinf                            VerbForm=Inf      0.0
# 7753           VERppe                VerbForm=Part|Tense=Past      0.0
# 7754           VERppe                VerbForm=Part|Tense=Past      0.0
# 7755           VERppe                VerbForm=Part|Tense=Past      0.0
# 8636           VERcjg                            VerbForm=Fin      0.0
# 8637           VERcjg                            VerbForm=Fin      0.0
# 8644           VERcjg                            VerbForm=Fin      0.0
# 8847           VERcjg                            VerbForm=Fin      0.0
# 8848           VERcjg                            VerbForm=Fin      0.0
# 8861           VERinf                            VerbForm=Inf      0.0
# 8896           VERppe                VerbForm=Part|Tense=Past      0.0
# 8939           VERcjg                            VerbForm=Fin      0.0
# 8972           VERppe                VerbForm=Part|Tense=Past      0.0
# 9381           VERcjg                            VerbForm=Fin      0.0
# 9391           ADJqua                                       _      0.0
# 9392           VERcjg                            VerbForm=Fin      0.0
# 9393           ADJqua                                       _      0.0
# 9394           VERcjg                            VerbForm=Fin      0.0
# 11585          VERinf                            VerbForm=Inf      0.0
# 11601          VERcjg                            VerbForm=Fin      0.0
# 11602          VERcjg                            VerbForm=Fin      0.0
# 11603          VERcjg                            VerbForm=Fin      0.0
# 11622          VERppe                VerbForm=Part|Tense=Past      0.0
# 15653          VERcjg                            VerbForm=Fin      0.0
# 15661          VERcjg                            VerbForm=Fin      0.0
# 15667          VERinf                            VerbForm=Inf      0.0
# 15671          VERcjg                            VerbForm=Fin      0.0
# 15707          VERcjg                            VerbForm=Fin      0.0
# 15715          VERcjg                            VerbForm=Fin      0.0
# 15721          VERinf                            VerbForm=Inf      0.0
# 15725          VERcjg                            VerbForm=Fin      0.0
# 16147          VERppe                VerbForm=Part|Tense=Past      0.0
# 16148          VERppe                VerbForm=Part|Tense=Past      0.0
# 16149          VERppe                VerbForm=Part|Tense=Past      0.0
# 17158          VERcjg                            VerbForm=Fin      0.0
# 17159          VERcjg                            VerbForm=Fin      0.0
# 17160          VERinf                            VerbForm=Inf      0.0
# 17290          VERppe                VerbForm=Part|Tense=Past      0.0
# 17291          VERppe                VerbForm=Part|Tense=Past      0.0
# 17292          VERppe                VerbForm=Part|Tense=Past      0.0
# 17309          VERppe                VerbForm=Part|Tense=Past      0.0
# 18218          VERcjg                            VerbForm=Fin      0.0
#
#                      file_src
# 3818   ../ofrlex-dev\VERB.lex
# 3819   ../ofrlex-dev\VERB.lex
# 4197   ../ofrlex-dev\VERB.lex
# 5248   ../ofrlex-dev\VERB.lex
# 5451   ../ofrlex-dev\VERB.lex
# 6973   ../ofrlex-dev\VERB.lex
# 6989   ../ofrlex-dev\VERB.lex
# 6990   ../ofrlex-dev\VERB.lex
# 7736   ../ofrlex-dev\VERB.lex
# 7753   ../ofrlex-dev\VERB.lex
# 7754   ../ofrlex-dev\VERB.lex
# 7755   ../ofrlex-dev\VERB.lex
# 8636   ../ofrlex-dev\VERB.lex
# 8637   ../ofrlex-dev\VERB.lex
# 8644   ../ofrlex-dev\VERB.lex
# 8847   ../ofrlex-dev\VERB.lex
# 8848   ../ofrlex-dev\VERB.lex
# 8861   ../ofrlex-dev\VERB.lex
# 8896   ../ofrlex-dev\VERB.lex
# 8939   ../ofrlex-dev\VERB.lex
# 8972   ../ofrlex-dev\VERB.lex
# 9381   ../ofrlex-dev\VERB.lex
# 9391   ../ofrlex-dev\VERB.lex
# 9392   ../ofrlex-dev\VERB.lex
# 9393   ../ofrlex-dev\VERB.lex
# 9394   ../ofrlex-dev\VERB.lex
# 11585  ../ofrlex-dev\VERB.lex
# 11601  ../ofrlex-dev\VERB.lex
# 11602  ../ofrlex-dev\VERB.lex
# 11603  ../ofrlex-dev\VERB.lex
# 11622  ../ofrlex-dev\VERB.lex
# 15653  ../ofrlex-dev\VERB.lex
# 15661  ../ofrlex-dev\VERB.lex
# 15667  ../ofrlex-dev\VERB.lex
# 15671  ../ofrlex-dev\VERB.lex
# 15707  ../ofrlex-dev\VERB.lex
# 15715  ../ofrlex-dev\VERB.lex
# 15721  ../ofrlex-dev\VERB.lex
# 15725  ../ofrlex-dev\VERB.lex
# 16147  ../ofrlex-dev\VERB.lex
# 16148  ../ofrlex-dev\VERB.lex
# 16149  ../ofrlex-dev\VERB.lex
# 17158  ../ofrlex-dev\VERB.lex
# 17159  ../ofrlex-dev\VERB.lex
# 17160  ../ofrlex-dev\VERB.lex
# 17290  ../ofrlex-dev\VERB.lex
# 17291  ../ofrlex-dev\VERB.lex
# 17292  ../ofrlex-dev\VERB.lex
# 17309  ../ofrlex-dev\VERB.lex
# 18218  ../ofrlex-dev\VERB.lex
